# %% [markdown]
# <a href="https://colab.research.google.com/github/kimlouisev/data-visualization/blob/main/Exploring_HIV_Incidence_and_Service_Access_in_New_York_City_(2016%E2%80%932021).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploring HIV Incidence and Service Access in New York City (2016–2021)

# %% [markdown]
# ## I. Introduction

# %% [markdown]
# 🔴 **What is HIV and AIDS?**
#
#  The World Health Organization (WHO) defines the [Human immunodeficiency virus (HIV)](https://www.who.int/news-room/fact-sheets/detail/hiv-aids) as a virus that targets the body's white blood cells and attacks the body’s immune system. This makes it easier to get sick with diseases like tuberculoses, infections and some cancers. HIV can be prevented and treated with antiretroviral therapy (ART), but left untreated, it can progress to the most advanced stage of infection, which is Acquired immunodeficiency syndrome (AIDS). With effective treatment, people with HIV can live a near-normal life expectancy, but without treatment, life expectancy can be significantly shortened, often leading to death within a few years of developing AIDS.
#
# 🔴 **HIV in NYC, Then**
#
# In the 1980s, New York City was at the epicenter of the AIDS crisis in the United States. By 1983, the city had already reported 1,000 AIDS cases, and by 1987, an estimated 70,000 New Yorkers were living with the disease—accounting for nearly 30% of all U.S. cases at the time. The epidemic disproportionately affected gay men, leading to widespread stigma and discrimination. Dubbed “gay pneumonia” due to misconceptions about its origins, AIDS fueled violence, job loss, and housing instability for many in the LGBTQ+ community. It also significantly affected minority groups, namely black, hispanic and poor individuals.[More on the history of HIV and AIDS in NYC here.](https://blogs.shu.edu/nyc-history/aids-crisis/) Fear and marginalization defined the epidemic’s early years, but activism drove progress in research, treatment, and policy.

# %%
from IPython.display import display, HTML

html_code = """
<div style="text-align: center;">
    <img src="https://blogs.shu.edu/nyc-history/files/2017/12/index-8-682x500.jpg" width="400" height="300"/>
    <p><strong>Figure 1: An advertisement in the 80s that calls attention to minority groups that were suffering from AIDS in America. </strong></p>
</div>
"""

display(HTML(html_code))
# Out:
# <div style="text-align: center;">
#     <img src="https://blogs.shu.edu/nyc-history/files/2017/12/index-8-682x500.jpg" width="400" height="300"/>
#     <p><strong>Figure 1: An advertisement in the 80s that calls attention to minority groups that were suffering from AIDS in America. </strong></p>
# </div>

# %% [markdown]
# 🔴 **HIV in NYC, Now**
#
# HIV remains a public health concern, but advancements in treatment and prevention have reduced overall cases. This blog examines NYC’s latest HIV data, highlighting the most affected populations and areas for improved support.
#
# [*Note: This blog focuses on HIV cases rather than AIDS for brevity. However, since HIV leads to AIDS, the insights remain relevant for AIDS prevention efforts as well.*]

# %% [markdown]
# ## II. Research Questions

# %% [markdown]
# In this blog, I will try to answer the following questions using recent data available in New York City:
#
# - Which boroughs and neighborhoods in NYC had the highest number of HIV cases from the years 2016 to 2021?
# - Which sex and race/ethnicity in NYC had the highest number of HIV cases from the years 2016 to 2021?
# - Is poverty correlated with HIV cases?
# - Are high burden areas within close proximity to organizations that offer HIV services (diagnostic, treatment, education and counselling)?

# %% [markdown]
# ## III. Hypothesis

# %% [markdown]
# Given the history of HIV in New York City and the broader United States, my hypothesis is that people living in Bronx or Brooklyn, men and black individuals will have the highest number of HIV cases. I suspect that incidence of HIV increases as poverty increases, yet I am not entirely certain how strong this association is. Further, given the historical trend of HIV being more common among gay men, I predict that there will be a higher incidence of HIV cases among men compared to women in New York City. Finally, given the activism of the past four decades around detecting and treating HIV in the city, I posit that organizations providing HIV services are generally present at or in close proximity to high burden areas.

# %% [markdown]
# ## IV. About the Data

# %% [markdown]
# To answer the above questions, I will use three datasets from New York City Open Data and New York City government Data Portal.
#
# - [Diagnoses of HIV/AIDS by Year, Neighborhood, Sex, and Race/Ethnicity](https://https://data.cityofnewyork.us/Health/HIV-AIDS-Diagnoses-by-Neighborhood-Sex-and-Race-Et/ykvb-493p/about_data) - This dataset from NYC Open Data includes data on new diagnoses of HIV and AIDS in NYC for the calendar years 2016 through 2021. Reported cases and case rates (per 100,000 population) are stratified by neighborhoods, sex, and race/ethnicity.
#
# - [Neighborhood poverty by UHF 42](https://https://a816-dohbesp.nyc.gov/IndicatorPublic/data-explorer/economic-conditions/?id=103#display=summary) - Data from the NYC.gov Environment and Health Data Portal. This dataset shows the percent of households with incomes below the federal poverty level from 2017-2021 at the neighborhood level.
#
# - [DOHMH HIV Service Directory](https://data.cityofnewyork.us/dataset/DOHMH-HIV-Service-Directory/pwts-g83w/about_data) - This dataset from NYC Open Data was compiled as a guide for persons living with HIV in New York City seeking HIV medical and supportive services. It compiles different organizations that receive CDC and Ryan White Part-A funding and their location throughout New York City. These organizations provide a range of services, including: Targeted-Testing among Priority Populations, Food and Nutrition Services, Health Education and Risk Reduction Services, Harm Reduction Services, Legal Services, Mental Health Services, Case Management and Care Coordination Services, and Supportive Counseling Services.

# %% [markdown]
# 🔴 **Notes**
#
# In this blog, I use the **number of HIV cases per 100,000 people** rather than the total number of HIV cases. This helps provide a clearer comparison between different populations or areas, as it accounts for the size of each population, making it easier to understand the rate of HIV in each group. In epidemiology, using cases per 100,000 is a common practice to standardize data across different population sizes. It allows for more meaningful comparisons between regions or groups, regardless of their population size, and helps highlight areas with higher or lower rates of disease.
#
# Throughout the blog, I will use the **United Hospital Fund (UHF) neighborhoods** in New York City to spatially disaggregate data. These are a set of geographic areas used for health data collection and analysis. These neighborhoods were defined by the United Hospital Fund, a New York-based nonprofit organization focused on health care and public health, to help examine health disparities across different areas of the city.

# %% [markdown]
# ## V. Methodology
#
# My methodology consists of three main steps:
# 1.   Loading the datasets
# 2.   Cleaning the datasets
# 3.   Performing analysis and visualization

# %% [markdown]
# ### A. Loading the three datasets

# %% [markdown]
# First, I loaded the HIV/AIDS case count data from 2016-2021 from NYC Open Data.

# %%
# setup
import pandas as pd
import plotly.express as px

# mount google drive
from google.colab import drive
drive.mount('/content/drive')

# load hiv data
df_hiv = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/HIV_AIDS_Diagnoses_by_Neighborhood__Sex__and_Race_Ethnicity_20250223.csv")

# display
df_hiv.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    YEAR Borough    Neighborhood (U.H.F)     SEX   RACE/ETHNICITY  \
# 0  2010     NaN              Greenpoint    Male            Black
# 1  2011     NaN  Stapleton - St. George  Female  Native American
# 2  2010     NaN        Southeast Queens    Male              All
# 3  2012     NaN          Upper Westside  Female          Unknown
# 4  2013     NaN             Willowbrook    Male          Unknown
#
#   TOTAL NUMBER OF HIV DIAGNOSES HIV DIAGNOSES PER 100,000 POPULATION  \
# 0                             6                                330.4
# 1                             0                                    0
# 2                            23                                 25.4
# 3                             0                                    0
# 4                             0                                    0
#
#   TOTAL NUMBER OF CONCURRENT HIV/AIDS DIAGNOSES  \
# 0                                             0
# 1                                             0
# 2                                             5
# 3                                             0
# 4                                             0
#
#   PROPORTION OF CONCURRENT HIV/AIDS DIAGNOSES AMONG ALL HIV DIAGNOSES  \
# 0                                                  0
# 1                                                  0
# 2                                               21.7
# 3                                                  0
# 4                                                  0
#
#   TOTAL NUMBER OF AIDS DIAGNOSES AIDS DIAGNOSES PER 100,000 POPULATION
# 0                              5                                 275.3
# 1                              0                                     0
# 2                             14                                  15.4
# 3                              0                                     0
# 4                              0                                     0

# %% [markdown]
# Next, I loaded the NYC.gov's neighborhood poverty rates.

# %%
# load neighborhood poverty data
df_pov_neigh = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/NYC EH Data Portal - Neighborhood poverty (uhf42).csv")

# display
df_pov_neigh.head()
# Out:
#   TimePeriod GeoTypeDesc  GeoID  GeoRank                Geography  Number  \
# 0    2017-21      UHF 42    101        4  Kingsbridge - Riverdale  14,713
# 1    2017-21      UHF 42    102        4          Northeast Bronx  30,694
# 2    2017-21      UHF 42    103        4       Fordham - Bronx Pk  73,579
# 3    2017-21      UHF 42    104        4     Pelham - Throgs Neck  61,654
# 4    2017-21      UHF 42    105        4         Crotona -Tremont  73,064
#
#    Percent
# 0     16.2
# 1     14.8
# 2     27.7
# 3     20.3
# 4     33.6

# %% [markdown]
# Finally, I loaded the DOHMH HIV Service Directory dataset from NYC Open Data.

# %%
# load hiv_service
df_hiv_serv = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DOHMH_HIV_Service_Directory_20250223.csv")

# display
df_hiv_serv.head(5)
# Out:
#                      FacilityName  \
# 0      African Services Committee
# 1             After Hours Project
# 2    AIDS Center of Queens County
# 3  APICHA Community Health Center
# 4                 Argus Community
#
#                                         Service Type                Address  \
# 0  Supportive Counseling Services, Legal Services...  429 West 127th Street
# 1  Short-Term Housing, Short-Term Rental Assistan...          1204 Broadway
# 2  Harm Reduction, Mental Health, Supportive Coun...  161-21 Jamaica Avenue
# 3                                  Care Coordination           400 Broadway
# 4                                  Care Coordination  760 East 160th Street
#
#    Address 2    Borough  ZipCode                         Website  \
# 0        NaN  Manhattan    10027     http://africanservices.org/
# 1        NaN   Brooklyn    11221      www.afterhoursproject.org/
# 2        NaN     Queens    11432                http://acqc.org/
# 3        NaN  Manhattan    10013             https://apicha.org/
# 4        NaN      Bronx    10456  http://www.arguscommunity.org/
#
#                       Email       Contacts' Email Secondary Email  \
# 0  info@africanservices.org                   NaN             NaN
# 1                       NaN                   NaN             NaN
# 2                       NaN  (718)-896-2500 x5736             NaN
# 3                       NaN          646-744-2591             NaN
# 4   info@arguscommunity.org        (718) 401-5715             NaN
#
#   Organization Phone                                      Contact Phone  \
# 0         2122223882  mulusewb@africanservices.org, paolar@africanse...
# 1         7182490755  emosquera@afterhoursproject.org, pbriones@afte...
# 2         7188962500  lanhalt@acqc.org, rlopez@acqc.org, evasquez@ac...
# 3         2123347940           tau@apicha.org, vvacharakitja@apicha.org
# 4         7184015715                     marodriguez@arguscommunity.org
#
#     Latitude  Longitude  Community Board  City Council District        BIN  \
# 0  40.813002 -73.953849            109.0                    7.0  1084104.0
# 1  40.692107 -73.926657            303.0                   41.0  3399422.0
# 2  40.704249 -73.797921            412.0                   27.0  4208875.0
# 3  40.718702 -74.002464            101.0                    1.0  1002334.0
# 4  40.820438 -73.904737            201.0                   17.0  2004691.0
#
#             BBL  Census Tract (2020) Neighborhood Tabulation Area (NTA) (2020)
# 0  1.019670e+09              21303.0                                    MN0902
# 1  3.016130e+09                387.0                                    BK0302
# 2  4.097608e+09              44601.0                                    QN1201
# 3  1.001960e+09                 31.0                                    MN0102
# 4  2.026560e+09                 77.0                                    BX0102

# %% [markdown]
# ### B. Cleaning the datasets
#
# After loading the data, I cleaned the dataset on HIV cases and neighborhood poverty rate, so that I can merge them later on.

# %% [markdown]
# First, I cleaned the HIV/AIDS case count data from 2016-2021 by removing aggregate rows and cleaning the values in the rows and columns.

# %%
#-------------------------#
# Removing aggregate rows #
#-------------------------#

# clean df_hiv by removing rows where "borough" is blank, "All" and NaN
df_hiv_clean = df_hiv[(df_hiv["Borough"] != "") & (df_hiv["Borough"] != "All") & (df_hiv["Borough"].notna())]

# clean df_hiv by removing rows where Neighborhood (U.H.F.) is "All"
df_hiv_clean = df_hiv_clean[df_hiv_clean["Neighborhood (U.H.F)"] != "All"]

# clean df_hiv by removing rows where Sex is "All"
df_hiv_clean = df_hiv_clean[df_hiv_clean["SEX"] != "All"]

# clean df_hiv by removing rows where Race/Ethnicity is "All"
df_hiv_clean = df_hiv_clean[df_hiv_clean["RACE/ETHNICITY"] != "All"]

#--------------------------------#
# Cleaning values in cols & rows #
#--------------------------------#

# rename values "Staten\nIsland" under borough
df_hiv_clean["Borough"] = df_hiv_clean["Borough"].replace("Staten\nIsland", "Staten Island")

# change all column titles to be lowercase
df_hiv_clean.columns = df_hiv_clean.columns.str.lower()

# make values in certain columns integers
df_hiv_clean["total number of hiv diagnoses"] = pd.to_numeric(df_hiv_clean["total number of hiv diagnoses"])
df_hiv_clean["hiv diagnoses per 100,000 population"] = pd.to_numeric(df_hiv_clean["hiv diagnoses per 100,000 population"])
df_hiv_clean["total number of aids diagnoses"] = pd.to_numeric(df_hiv_clean["total number of aids diagnoses"])
df_hiv_clean["aids diagnoses per 100,000 population"] = pd.to_numeric(df_hiv_clean["aids diagnoses per 100,000 population"])

# remove instances of "\n" in neighborhood (u.h.f) column
df_hiv_clean["neighborhood (u.h.f)"] = df_hiv_clean["neighborhood (u.h.f)"].str.replace("\n", " ", regex=False)

# display
df_hiv_clean.head()
# Out:
#       year borough neighborhood (u.h.f)     sex           race/ethnicity  \
# 2971  2016   Bronx    Crotona - Tremont  Female  Asian/Pacific\nIslander
# 2972  2016   Bronx    Crotona - Tremont  Female                    Black
# 2973  2016   Bronx    Crotona - Tremont  Female          Latino/Hispanic
# 2974  2016   Bronx    Crotona - Tremont  Female            Other/Unknown
# 2975  2016   Bronx    Crotona - Tremont  Female                    White
#
#       total number of hiv diagnoses  hiv diagnoses per 100,000 population  \
# 2971                            0.0                                   0.0
# 2972                           10.0                                  38.7
# 2973                           14.0                                  22.0
# 2974                            0.0                                   0.0
# 2975                            2.0                                 130.6
#
#      total number of concurrent hiv/aids diagnoses  \
# 2971                                             0
# 2972                                             0
# 2973                                             2
# 2974                                             0
# 2975                                             0
#
#      proportion of concurrent hiv/aids diagnoses among all hiv diagnoses  \
# 2971                                                NaN
# 2972                                                  0
# 2973                                               14.3
# 2974                                                NaN
# 2975                                                  0
#
#       total number of aids diagnoses  aids diagnoses per 100,000 population
# 2971                             1.0                                   63.3
# 2972                            10.0                                   38.7
# 2973                            12.0                                   18.9
# 2974                             0.0                                    0.0
# 2975                             0.0                                    0.0

# %% [markdown]
# Next, I cleaned the neighborhood poverty rate dataset by retaining only the relevant columns for my analysis and renaming the headers & some values to make merging easier.

# %%
# remove columns 'TimePeriod', 'GeoTypeDesc', 'GeoID', 'GeoRank'
df_pov_neigh = df_pov_neigh.drop(columns=['TimePeriod', 'GeoTypeDesc', 'GeoID', 'GeoRank'])

# renaming columns
df_pov_neigh = df_pov_neigh.rename(columns={'Geography': 'neighborhood (u.h.f)'})
df_pov_neigh = df_pov_neigh.rename(columns={'Number': 'no. of people in poverty (2017-2021)'})
df_pov_neigh = df_pov_neigh.rename(columns={'Percent': 'poverty rate (2017-2021)'})

# renaming values in columns to merge with df_hiv_clean
df_pov_neigh["neighborhood (u.h.f)"] = df_pov_neigh["neighborhood (u.h.f)"].replace("Fordham - Bronx Pk", "Fordham - Bronx Park", regex=False)
df_pov_neigh["neighborhood (u.h.f)"] = df_pov_neigh["neighborhood (u.h.f)"].replace("Crotona -Tremont", "Crotona - Tremont", regex=False)


# display
df_pov_neigh.head()
# Out:
#       neighborhood (u.h.f) no. of people in poverty (2017-2021)  \
# 0  Kingsbridge - Riverdale                               14,713
# 1          Northeast Bronx                               30,694
# 2     Fordham - Bronx Park                               73,579
# 3     Pelham - Throgs Neck                               61,654
# 4        Crotona - Tremont                               73,064
#
#    poverty rate (2017-2021)
# 0                      16.2
# 1                      14.8
# 2                      27.7
# 3                      20.3
# 4                      33.6

# %% [markdown]
# ### C. Merging the datasets
#
# In this section, I combine the cleaned HIV/AIDs dataset with the cleaned neighborhood poverty dataset. This will be my main dataset for analysis and visualization.

# %% [markdown]
# Adding poverty data to the HIV dataset

# %%
# do an inner merge df_pov_neigh to df_hiv using the column "neighborhood (u.h.f)"
df_merged = pd.merge(df_hiv_clean, df_pov_neigh, on="neighborhood (u.h.f)", how="left")

# print
df_merged.head()
# Out:
#    year borough neighborhood (u.h.f)     sex           race/ethnicity  \
# 0  2016   Bronx    Crotona - Tremont  Female  Asian/Pacific\nIslander
# 1  2016   Bronx    Crotona - Tremont  Female                    Black
# 2  2016   Bronx    Crotona - Tremont  Female          Latino/Hispanic
# 3  2016   Bronx    Crotona - Tremont  Female            Other/Unknown
# 4  2016   Bronx    Crotona - Tremont  Female                    White
#
#    total number of hiv diagnoses  hiv diagnoses per 100,000 population  \
# 0                            0.0                                   0.0
# 1                           10.0                                  38.7
# 2                           14.0                                  22.0
# 3                            0.0                                   0.0
# 4                            2.0                                 130.6
#
#   total number of concurrent hiv/aids diagnoses  \
# 0                                             0
# 1                                             0
# 2                                             2
# 3                                             0
# 4                                             0
#
#   proportion of concurrent hiv/aids diagnoses among all hiv diagnoses  \
# 0                                                NaN
# 1                                                  0
# 2                                               14.3
# 3                                                NaN
# 4                                                  0
#
#    total number of aids diagnoses  aids diagnoses per 100,000 population  \
# 0                             1.0                                   63.3
# 1                            10.0                                   38.7
# 2                            12.0                                   18.9
# 3                             0.0                                    0.0
# 4                             0.0                                    0.0
#
#   no. of people in poverty (2017-2021)  poverty rate (2017-2021)
# 0                               73,064                      33.6
# 1                               73,064                      33.6
# 2                               73,064                      33.6
# 3                               73,064                      33.6
# 4                               73,064                      33.6

# %% [markdown]
# ### D. Analysis
#
# In this section, I investigate whether my hypothesis regarding the research questions are correct, given 2016-2021 data.

# %% [markdown]
# #### a. How many HIV cases per 100,000 by borough (total and per year)?
#
# 🔴 From 2016 to 2021, **Manhattan** had the highest rate of HIV diagnoses per 100,000 people, followed by Brooklyn, the Bronx, Queens, and Staten Island in that order.

# %%
# aggregate HIV cases per 100,000 by borough
hiv_bor = df_merged.groupby('borough')['hiv diagnoses per 100,000 population'].sum()

# display
hiv_bor

# creating a bar chart summarizing hiv cases per 100,000 by borough
fig_hiv_bor = px.bar(
    hiv_bor,
    x=hiv_bor.index,
    y='hiv diagnoses per 100,000 population',
    title = 'Total HIV cases per 100,000 (2016-2021) in NYC')

fig_hiv_bor.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="325fe7f8-6511-4b9a-9711-80873b53e67c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("325fe7f8-6511-4b9a-9711-80873b53e67c")) {                    Plotly.newPlot(                        "325fe7f8-6511-4b9a-9711-80873b53e67c",                        [{"alignmentgroup":"True","hovertemplate":"borough=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Bronx","Brooklyn","Manhattan","Queens","Staten Island"],"xaxis":"x","y":[13341.8,17457.5,24337.3,11618.1,4845.8],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scat ...

# %% [markdown]
# 🔴 When we disaggregate the number of HIV diagnoses per 100,000 from 2016-2021, we can see two striking observations:
# - Manhattan is the borough that consistently had the highest share of HIV diagnoses per 100,000.
# - There was an uptick in new HIV diagnoses in 2020.

# %%
# aggregate HIV cases per 100,000 by borough
hiv_bor_yr = df_merged.groupby(['year', 'borough'])['hiv diagnoses per 100,000 population'].sum().reset_index()

# display
hiv_bor_yr

# creating a bar chart summarizing hiv cases per 100,000 by borough
fig_hiv_bor_yr = px.bar(
    hiv_bor_yr,
    x='year',
    y='hiv diagnoses per 100,000 population',
    color= 'borough',
    title = 'Total HIV cases per 100,000 (2016-2021) by borough by year in NYC')

fig_hiv_bor_yr.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d9219936-bbb2-4ded-bac2-2033c1a3bd08" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9219936-bbb2-4ded-bac2-2033c1a3bd08")) {                    Plotly.newPlot(                        "d9219936-bbb2-4ded-bac2-2033c1a3bd08",                        [{"alignmentgroup":"True","hovertemplate":"borough=Bronx\u003cbr\u003eyear=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bronx","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Bronx","offsetgroup":"Bronx","orientation":"v","showlegend":true,"textposition":"auto","x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[2659.3,2065.1,1566.5,2034.7,3035.4,1980.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"borough=Brooklyn\u003cbr\u003eyear=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Brooklyn","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Brooklyn","offsetgroup":"Brooklyn","orientation":"v","showlegend":true,"textposition":"auto","x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[2944.7,3664.8,2478.9,2685.5,3463.2,2220.4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"borough=Manhattan\u003cbr\u003eyear=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Manhattan","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Manhattan","offsetgroup":"Manhattan","orientation":"v","showlegend":true,"textposition":"auto","x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[4069.6,4180.6,3735.0,3454.5,5627.0,3270.6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"borough=Queens\u003cbr\u003eyear=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Queens","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Queens","offsetgroup":"Queens","orientation":"v","showlegend":true,"textposition":"auto","x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[1818.5,1880.7,1745.4,1590.8,2870.3,1712.4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"borough=Staten Island\u003cbr\u003eyear=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Staten Island","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Staten Island","offsetgroup":"Staten Island","orientation":"v","showlegend":true,"textposition":"auto","x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[1710.4,722.8,394.9,305.8,1179.1,532.8],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a ...

# %% [markdown]
# #### b. How many HIV cases per 100,000 by race/ethnicity?

# %% [markdown]
# 🔴 From 2016 to 2021, **Black** individuals had the highest rate of HIV diagnoses per 100,000 people, making up 46% of all cases in that period. They are followed by Latino/Hispanic, Other, White, then Asian/Pacific Islander.

# %%
# aggregate HIV cases per 100,000 by race/ethnicity
hiv_race = df_merged.groupby('race/ethnicity')['hiv diagnoses per 100,000 population'].sum().reset_index()

# sort in descending order
hiv_race = hiv_race.sort_values(by='hiv diagnoses per 100,000 population', ascending=False)

# display
hiv_race

# creating a pie chart summarizing hiv cases per 100,000 by race/ethnicity
fig_hiv_race = px.pie(
    hiv_race,
    values='hiv diagnoses per 100,000 population',
    names='race/ethnicity',
    title='Total HIV cases per 100,000 (2016-2021) by race/ethnicity in NYC')

# display
fig_hiv_race.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="16baf5a1-6d60-42fc-8e65-cd081ee18d12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16baf5a1-6d60-42fc-8e65-cd081ee18d12")) {                    Plotly.newPlot(                        "16baf5a1-6d60-42fc-8e65-cd081ee18d12",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"race\u002fethnicity=%{label}\u003cbr\u003ehiv diagnoses per 100,000 population=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Black","Latino\u002fHispanic","Other\u002fUnknown","White","Asian\u002fPacific\nIslander"],"legendgroup":"","name":"","showlegend":true,"values":[32975.8,16882.0,8595.8,7497.0,5649.9],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"out ...

# %% [markdown]
# 🔴 When we disaggregate these figures across 2016-2021, we see that this trend is consistent across all years. Black individuals make up the largest share of new HIV diagnoses per 100,000. It's worth noting that the number of white individuals was larger than Other/Unknown in 2020 and 2021.

# %%
# aggregate HIV cases per 100,000 by race/ethnicity by year
hiv_race_yr = df_merged.groupby(['year', 'race/ethnicity'])['hiv diagnoses per 100,000 population'].sum().reset_index()

# display
hiv_race_yr

# creating a pie chart summarizing hiv cases per 100,000 by race/ethnicity
fig_hiv_race_yr = px.bar(
    hiv_race_yr,
    x='year',
    y='hiv diagnoses per 100,000 population',
    color='race/ethnicity',
    title='Total HIV cases per 100,000 (2016-2021) by race/ethnicity by year in NYC')


fig_hiv_race_yr.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="aca98a41-c414-4bd9-a0a5-d4ec080e1afc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aca98a41-c414-4bd9-a0a5-d4ec080e1afc")) {                    Plotly.newPlot(                        "aca98a41-c414-4bd9-a0a5-d4ec080e1afc",                        [{"alignmentgroup":"True","hovertemplate":"race\u002fethnicity=Asian\u002fPacific\nIslander\u003cbr\u003eyear=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asian\u002fPacific\nIslander","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Asian\u002fPacific\nIslander","offsetgroup":"Asian\u002fPacific\nIslander","orientation":"v","showlegend":true,"textposition":"auto","x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[1515.0,976.6,716.1,553.8,1149.4,739.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"race\u002fethnicity=Black\u003cbr\u003eyear=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Black","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Black","offsetgroup":"Black","orientation":"v","showlegend":true,"textposition":"auto","x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[5887.1,4970.7,4488.7,4317.7,8461.3,4850.3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"race\u002fethnicity=Latino\u002fHispanic\u003cbr\u003eyear=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latino\u002fHispanic","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Latino\u002fHispanic","offsetgroup":"Latino\u002fHispanic","orientation":"v","showlegend":true,"textposition":"auto","x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[2959.5,2840.8,2829.0,2598.7,3629.4,2024.6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"race\u002fethnicity=Other\u002fUnknown\u003cbr\u003eyear=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other\u002fUnknown","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Other\u002fUnknown","offsetgroup":"Other\u002fUnknown","orientation":"v","showlegend":true,"textposition":"auto","x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[1561.6,2485.9,942.5,1683.3,1105.5,817.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"race\u002fethnicity=White\u003cbr\u003eyear=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"White","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"White","offsetgroup":"White","orientation":"v","showlegend":true,"textposition":"auto","x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[1279.3,1240.0,944.4,917.8,1829.3999999999999,1286.1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"], ...

# %% [markdown]
# #### c. How many HIV cases per 100,000 by sex (total and per year)?

# %% [markdown]
# 🔴 From 2016 to 2021, **men** had the highest rate of HIV diagnoses per 100,000 people at 85% compared to women at 15%.

# %%
# aggregate HIV cases per 100,000 by sex
hiv_sex = df_merged.groupby('sex')['hiv diagnoses per 100,000 population'].sum().reset_index()

# display
hiv_sex

# creating a pie chart summarizing hiv cases per 100,000 by sex
fig_hiv_sex = px.pie(
    hiv_sex,
    values='hiv diagnoses per 100,000 population',
    names='sex',
    title='Total HIV cases per 100,000 (2016-2020) by gender in NYC')

fig_hiv_sex.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0f35233c-3b12-4314-87d3-78ad1a645b17" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f35233c-3b12-4314-87d3-78ad1a645b17")) {                    Plotly.newPlot(                        "0f35233c-3b12-4314-87d3-78ad1a645b17",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"sex=%{label}\u003cbr\u003ehiv diagnoses per 100,000 population=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Female","Male"],"legendgroup":"","name":"","showlegend":true,"values":[11246.6,60353.9],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks ...

# %% [markdown]
# 🔴 When we disaggregate across 2016-2021, we see that men consistently have higher incidence of HIV than women.

# %%
# aggregate HIV cases per 100,000 by sex by year
hiv_sex_yr = df_merged.groupby(['year', 'sex'])['hiv diagnoses per 100,000 population'].sum().reset_index()

# display
hiv_sex_yr

# creating a pie chart summarizing hiv cases per 100,000 by sex
fig_hiv_sex_yr = px.bar(
    hiv_sex_yr,
    x='year',
    y='hiv diagnoses per 100,000 population',
    color= 'sex',
    title='Total HIV cases per 100,000 (2016-2021) by gender by year in NYC')


fig_hiv_sex_yr.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="08ff39da-0c17-42ff-aa0b-75be349da048" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08ff39da-0c17-42ff-aa0b-75be349da048")) {                    Plotly.newPlot(                        "08ff39da-0c17-42ff-aa0b-75be349da048",                        [{"alignmentgroup":"True","hovertemplate":"sex=Female\u003cbr\u003eyear=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":true,"textposition":"auto","x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[2199.0,1806.9,1669.1,1573.1,2270.8,1727.7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"sex=Male\u003cbr\u003eyear=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Male","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Male","offsetgroup":"Male","orientation":"v","showlegend":true,"textposition":"auto","x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[11003.5,10707.1,8251.6,8498.2,13904.2,7989.3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":" ...

# %% [markdown]
# #### d. Are HIV cases per 100,000 correlated with poverty rate?

# %% [markdown]
# 🔴 Next, I examine the correlation between HIV diagnoses per 100,000 and the poverty rate by neighborhood. The results indicate a small positive correlation, suggesting that as the poverty rate increases, the number of HIV diagnoses also tends to rise. However, the strength of this relationship is relatively weak. This is evident from the R² value in the regression analysis, which measures how well the trendline fits the data. With an R² of 0.091, the trendline does not align closely with the data points (an R² of 1.00 would indicate a perfect fit and a strong association). Additionally, the coefficient for the poverty rate (x1) has a p-value of 0.0664, which exceeds the conventional 5% significance threshold. This suggests that while there is a small positive association, it may not hold universally across all cases. Visually, the weak association is also apparent, as the trendline in the scatterplot does not closely follow the distribution of the data points.

# %%
# load statsmodel
#!pip install statsmodels
import statsmodels.api as sm
import statsmodels.formula.api as smf
import plotly.express as px

#-------

# filter only data in 2021
hiv_2021 = df_merged[df_merged["year"] == 2021]

# display
hiv_2021.head()

# aggregate hiv diagnoses and poverty rate by borough
hiv_pov_2021 = hiv_2021.groupby(['neighborhood (u.h.f)', 'poverty rate (2017-2021)'])['hiv diagnoses per 100,000 population'].sum().reset_index()

# display
hiv_pov_2021.head()
# Out:
#                  neighborhood (u.h.f)  poverty rate (2017-2021)  \
# 0               Bayside - Little Neck                       7.8
# 1  Bedford Stuyvesant - Crown Heights                      21.6
# 2             Bensonhurst - Bay Ridge                      14.4
# 3                        Borough Park                      21.8
# 4                Canarsie - Flatlands                      11.6
#
#    hiv diagnoses per 100,000 population
# 0                                   0.0
# 1                                 351.9
# 2                                  73.9
# 3                                 138.5
# 4                                 122.8

# %%
# scatterplot with y=hiv cases by boro, x=poverty rate by boro in 2019
fig_hiv_pov_2021 = px.scatter(
    hiv_pov_2021,
    x="poverty rate (2017-2021)",
    y="hiv diagnoses per 100,000 population",
    color="neighborhood (u.h.f)",
    title="Poverty rate vs. HIV cases per 100,000 (2021) by neighborhood in NYC",
    trendline="ols",
    trendline_scope="overall"
)

# display
fig_hiv_pov_2021.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="290da393-2710-46e6-8a41-720ea2a4cbd8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("290da393-2710-46e6-8a41-720ea2a4cbd8")) {                    Plotly.newPlot(                        "290da393-2710-46e6-8a41-720ea2a4cbd8",                        [{"hovertemplate":"neighborhood (u.h.f)=Bayside - Little Neck\u003cbr\u003epoverty rate (2017-2021)=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bayside - Little Neck","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Bayside - Little Neck","orientation":"v","showlegend":true,"x":[7.8],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"neighborhood (u.h.f)=Bedford Stuyvesant - Crown Heights\u003cbr\u003epoverty rate (2017-2021)=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bedford Stuyvesant - Crown Heights","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Bedford Stuyvesant - Crown Heights","orientation":"v","showlegend":true,"x":[21.6],"xaxis":"x","y":[351.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"neighborhood (u.h.f)=Bensonhurst - Bay Ridge\u003cbr\u003epoverty rate (2017-2021)=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bensonhurst - Bay Ridge","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Bensonhurst - Bay Ridge","orientation":"v","showlegend":true,"x":[14.4],"xaxis":"x","y":[73.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"neighborhood (u.h.f)=Borough Park\u003cbr\u003epoverty rate (2017-2021)=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Borough Park","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Borough Park","orientation":"v","showlegend":true,"x":[21.8],"xaxis":"x","y":[138.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"neighborhood (u.h.f)=Canarsie - Flatlands\u003cbr\u003epoverty rate (2017-2021)=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Canarsie - Flatlands","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Canarsie - Flatlands","orientation":"v","showlegend":true,"x":[11.6],"xaxis":"x","y":[122.8],"yaxis":"y","type":"scatter"},{"hovertemplate":"neighborhood (u.h.f)=Central Harlem - Morningside Heights\u003cbr\u003epoverty rate (2017-2021)=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Central Harlem - Morningside Heights","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Central Harlem - Morningside Heights","orientation":"v","showlegend":true,"x":[23.9],"xaxis":"x","y":[337.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"neighborhood (u.h.f)=Chelsea - Clinton\u003cbr\u003epoverty rate (2017-2021)=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chelsea - Clinton","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Chelsea - Clinton","orientation":"v","showlegend":true,"x":[11.9],"xaxis":"x","y":[690.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"neighborhood (u.h.f)=Coney Island - Sheepshead Bay\u003cbr\u003epoverty rate (2017-2021)=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Coney Island - Sheepshead Bay","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Coney Island - Sheepshead Ba ...

# %%
# get regression results
trend_results = px.get_trendline_results(fig_hiv_pov_2021).iloc[0, 0]
trend_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     3.585
# Date:                Tue, 04 Mar 2025   Prob (F-statistic):             0.0664
# Time:                        01:54:35   Log-Likelihood:                -241.32
# No. Observations:                  38   AIC:                             486.6
# Df Residuals:                      36   BIC:                             489.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        147.9607     52.436      2.822      0.008      41.616     254.305
# x1             5.2828      2.790      1.893      0.066      -0.376      10.942
# ==============================================================================
# Omnibus:                       16.490   Durbin-Watson:                   2.343
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.539
# Skew:                           1.378   Prob(JB):                     5.72e-05
# Kurtosis:                       5.179   Cond. No.                         42.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### e. How many HIV cases per 100,000 by neighborhood?

# %% [markdown]
# 🔴 Although we know that **Manhattan** has the highest number of HIV diagnoses per 100,000, it is useful to know which neighborhoods have the highest incidence. When we disaggregate the numbers from 2016-2021, we can see that **Chelsea - Clinton** and **Greenwich Village and Soho** have the highest incidence. The next big areas with high incidence are parts of Bronx (**Hunts Point - Mott Haven** and **Crotona - Tremont**) and Brooklyn (**Bedford Stuyvesant - Crown Heights** and **East New York**). We can see from the map on poverty rates by neighborhood (2017 - 2021) that these are neighborhoods that have the highest poverty rates, therefore corroborating our earlier finding that HIV cases are somewhat correlated with poverty rate. We can see this in both the bar graphs by neighborhood and in the maps for HIV diagnoses by neighborhood and poverty rate by neighborhood.

# %%
# aggregate HIV cases per 100,000 by UHF neighborhood
hiv_uhf = df_merged.groupby(['borough', 'neighborhood (u.h.f)'])['hiv diagnoses per 100,000 population'].sum().reset_index()

# sort in descending order based on hiv diagnoses column
hiv_uhf = hiv_uhf.sort_values(by='hiv diagnoses per 100,000 population', ascending=False)

# display
hiv_uhf.head()
# Out:
#       borough                neighborhood (u.h.f)  \
# 19  Manhattan                   Chelsea - Clinton
# 22  Manhattan            Greenwich Village - Soho
# 0       Bronx                   Crotona - Tremont
# 3       Bronx            Hunts Point - Mott Haven
# 7    Brooklyn  Bedford Stuyvesant - Crown Heights
#
#     hiv diagnoses per 100,000 population
# 19                                4408.8
# 22                                3771.3
# 0                                 2911.8
# 3                                 2790.3
# 7                                 2683.6

# %%
# rename values under neighborhood (u.h.f) column for mapping
hiv_uhf["neighborhood (u.h.f)"] = hiv_uhf["neighborhood (u.h.f)"].replace("Downtown - Heights - Park Slope", "Downtown  - Heights - Slope", regex=False)
hiv_uhf["neighborhood (u.h.f)"] = hiv_uhf["neighborhood (u.h.f)"].replace("Gramercy Park - Murray Hill", "Gramercy Park -  Murray Hill", regex=False)
hiv_uhf["neighborhood (u.h.f)"] = hiv_uhf["neighborhood (u.h.f)"].replace("Port Richmond", "Port  Richmond", regex=False)

# creating a bar chart summarizing hiv cases per 100,000 by borough without legend
fig_hiv_uhf = px.bar(
    hiv_uhf,
    x='neighborhood (u.h.f)',
    y='hiv diagnoses per 100,000 population',
    color="borough",
    title='Total HIV cases per 100,000 (2016-2021) in NYC')

fig_hiv_uhf.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1bd32c35-5ad1-4126-9a12-6f706976762c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1bd32c35-5ad1-4126-9a12-6f706976762c")) {                    Plotly.newPlot(                        "1bd32c35-5ad1-4126-9a12-6f706976762c",                        [{"alignmentgroup":"True","hovertemplate":"borough=Manhattan\u003cbr\u003eneighborhood (u.h.f)=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Manhattan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Manhattan","offsetgroup":"Manhattan","orientation":"v","showlegend":true,"textposition":"auto","x":["Chelsea - Clinton","Greenwich Village - Soho","East Harlem","Washington Heights - Inwood","Central Harlem - Morningside Heights","Lower Manhattan","Gramercy Park -  Murray Hill","Union Square - Lower East Side","Upper West Side","Upper East Side"],"xaxis":"x","y":[4408.8,3771.2999999999997,2525.7999999999997,2467.4,2448.4,2044.7,1881.7,1836.4,1564.0,1388.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"borough=Bronx\u003cbr\u003eneighborhood (u.h.f)=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bronx","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Bronx","offsetgroup":"Bronx","orientation":"v","showlegend":true,"textposition":"auto","x":["Crotona - Tremont","Hunts Point - Mott Haven","High Bridge - Morrisania","Fordham - Bronx Park","Pelham - Throgs Neck","Northeast Bronx","Kingsbridge - Riverdale"],"xaxis":"x","y":[2911.8,2790.3,2517.4,1793.0,1519.1000000000001,1015.1,795.1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"borough=Brooklyn\u003cbr\u003eneighborhood (u.h.f)=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Brooklyn","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Brooklyn","offsetgroup":"Brooklyn","orientation":"v","showlegend":true,"textposition":"auto","x":["Bedford Stuyvesant - Crown Heights","East New York","Williamsburg - Bushwick","East Flatbush - Flatbush","Sunset Park","Greenpoint","Downtown  - Heights - Slope","Coney Island - Sheepshead Bay","Canarsie - Flatlands","Bensonhurst - Bay Ridge","Borough Park"],"xaxis":"x","y":[2683.6,2434.8,2262.4,2019.0,1808.7,1404.3,1241.0,1041.5,917.6,847.0,797.6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"borough=Queens\u003cbr\u003eneighborhood (u.h.f)=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Queens","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Queens","offsetgroup":"Queens","orientation":"v","showlegend":true,"textposition":"auto","x":["Long Island City - Astoria","Ridgewood - Forest Hills","Flushing - Clearview","West Queens","Jamaica","Southwest Queens","Rockaway","Southeast Queens","Fresh Meadows","Bayside - Little Neck"],"xaxis":"x","y":[2134.3,2013.4,1237.6,1236.1,1164.4,1135.1,919.0,810.6,749.3,218.3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"borough=Staten Island\u003cbr\u003eneighborhood (u.h.f)=%{x}\u003cbr\u003ehiv diagnoses per 100,000 population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Staten Island","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Staten Island","offsetgroup":"Staten Island","orientation":"v","showlegend":true,"textposition":"auto","x":["South Beach - Tottenville","Willowbrook","Stapleton - St. George","Port  Richmond"],"xaxis":"x","y":[1502.5,1169.6,1091.0,1082.7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histog ...

# %%
import requests

response = requests.get(
    "https://raw.githubusercontent.com/nycehs/NYC_geography/refs/heads/master/UHF42.geo.json"
)
geojson = response.json()

geojson['features'][1]['properties']
# Out:
# {'GEOCODE': 102, 'GEONAME': 'Northeast Bronx', 'BOROUGH': 'Bronx'}

# %%
fig_hiv_uhf_map = px.choropleth_mapbox(hiv_uhf,
                           geojson=geojson,
                           locations='neighborhood (u.h.f)',
                           featureidkey='properties.GEONAME',
                           color='hiv diagnoses per 100,000 population',
                           hover_data=['neighborhood (u.h.f)'],
                           title='Total HIV cases per 100,000 by neighborhood (u.h.f)',
                           center = {'lat': 40.73, 'lon': -73.98},
                           zoom=10,
                           color_continuous_scale="YlOrRd",
                           mapbox_style='carto-positron')

fig_hiv_uhf_map.update_layout(height=1000)
fig_hiv_uhf_map.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="25034eba-4a86-4b96-bf2f-7b12cd48dc17" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25034eba-4a86-4b96-bf2f-7b12cd48dc17")) {                    Plotly.newPlot(                        "25034eba-4a86-4b96-bf2f-7b12cd48dc17",                        [{"coloraxis":"coloraxis","customdata":[["Chelsea - Clinton"],["Greenwich Village - Soho"],["Crotona - Tremont"],["Hunts Point - Mott Haven"],["Bedford Stuyvesant - Crown Heights"],["East Harlem"],["High Bridge - Morrisania"],["Washington Heights - Inwood"],["Central Harlem - Morningside Heights"],["East New York"],["Williamsburg - Bushwick"],["Long Island City - Astoria"],["Lower Manhattan"],["East Flatbush - Flatbush"],["Ridgewood - Forest Hills"],["Gramercy Park -  Murray Hill"],["Union Square - Lower East Side"],["Sunset Park"],["Fordham - Bronx Park"],["Upper West Side"],["Pelham - Throgs Neck"],["South Beach - Tottenville"],["Greenpoint"],["Upper East Side"],["Downtown  - Heights - Slope"],["Flushing - Clearview"],["West Queens"],["Willowbrook"],["Jamaica"],["Southwest Queens"],["Stapleton - St. George"],["Port  Richmond"],["Coney Island - Sheepshead Bay"],["Northeast Bronx"],["Rockaway"],["Canarsie - Flatlands"],["Bensonhurst - Bay Ridge"],["Southeast Queens"],["Borough Park"],["Kingsbridge - Riverdale"],["Fresh Meadows"],["Bayside - Little Neck"]],"featureidkey":"properties.GEONAME","geojson":{"type":"FeatureCollection","features":[{"type":"Feature","properties":{"GEOCODE":101,"GEONAME":"Kingsbridge - Riverdale","BOROUGH":"Bronx"},"geometry":{"type":"Polygon","coordinates":[[[-73.877928,40.905562],[-73.902168,40.912841],[-73.910731,40.915775],[-73.914292,40.904242],[-73.915148,40.903069],[-73.918149,40.89411],[-73.91976,40.89113],[-73.920557,40.887201],[-73.924678,40.8789],[-73.922779,40.878849],[-73.919803,40.876419],[-73.913012,40.874791],[-73.910341,40.873842],[-73.908772,40.871777],[-73.911053,40.866308],[-73.914343,40.862519],[-73.913605,40.862205],[-73.912918,40.861961],[-73.909044,40.862673],[-73.907102,40.867886],[-73.902659,40.870579],[-73.900964,40.875355],[-73.896691,40.880156],[-73.896377,40.881823],[-73.887102,40.882925],[-73.887068,40.8844],[-73.881243,40.882708],[-73.877987,40.887034],[-73.880404,40.892828],[-73.880107,40.8952],[-73.877928,40.905562]]]},"id":"101"},{"type":"Feature","properties":{"GEOCODE":102,"GEONAME":"Northeast Bronx","BOROUGH":"Bronx"},"geometry":{"type":"Polygon","coordinates":[[[-73.815044,40.889002],[-73.822852,40.891207],[-73.823268,40.889989],[-73.838046,40.894142],[-73.839648,40.897327],[-73.83925,40.8995],[-73.841386,40.904159],[-73.844761,40.904242],[-73.845388,40.905639],[-73.850204,40.907478],[-73.853536,40.907465],[-73.857529,40.904793],[-73.857232,40.903024],[-73.859682,40.902294],[-73.859326,40.900589],[-73.874248,40.904806],[-73.877928,40.905562],[-73.880107,40.8952],[-73.870484,40.896642],[-73.861361,40.894661],[-73.865371,40.886874],[-73.855884,40.883861],[-73.856266,40.88315],[-73.861073,40.87447],[-73.861794,40.857986],[-73.861836,40.857383],[-73.849483,40.858107],[-73.83802,40.856947],[-73.833077,40.857537],[-73.830661,40.857069],[-73.827414,40.859595],[-73.826117,40.856677],[-73.823081,40.857017],[-73.818672,40.858806],[-73.816604,40.860935],[-73.819368,40.859249],[-73.821199,40.859441],[-73.819113,40.862],[-73.820216,40.862923],[-73.821004,40.868046],[-73.823726,40.869758],[-73.823938,40.874073],[-73.821877,40.879246],[-73.820834,40.884855],[-73.819359,40.885727],[-73.81534,40.886778],[-73.815044,40.889002]]]},"id":"102"},{"type":"Feature","properties":{"GEOCODE":103,"GEONAME":"Fordham - Bronx Park","BOROUGH":"Bronx"},"geometry":{"type":"Polygon","coordinates":[[[-73.856266,40.88315],[-73.855884,40.883861],[-7 ...

# %% [markdown]
# Poverty rate by neighborhoods

# %%
# rename values under neighborhood (u.h.f) column for mapping
df_pov_neigh["neighborhood (u.h.f)"] = df_pov_neigh["neighborhood (u.h.f)"].replace("Downtown - Heights - Slope", "Downtown  - Heights - Slope", regex=False)
df_pov_neigh["neighborhood (u.h.f)"] = df_pov_neigh["neighborhood (u.h.f)"].replace("Gramercy Park - Murray Hill", "Gramercy Park -  Murray Hill", regex=False)
df_pov_neigh["neighborhood (u.h.f)"] = df_pov_neigh["neighborhood (u.h.f)"].replace("Port Richmond", "Port  Richmond", regex=False)
df_pov_neigh["neighborhood (u.h.f)"] = df_pov_neigh["neighborhood (u.h.f)"].replace("Washington Heights", "Washington Heights - Inwood", regex=False)
df_pov_neigh["neighborhood (u.h.f)"] = df_pov_neigh["neighborhood (u.h.f)"].replace("Greenwich Village - SoHo", "Greenwich Village - Soho", regex=False)


# graphing
fig_pov_neigh_map = px.choropleth_mapbox(df_pov_neigh,
                           geojson=geojson,
                           locations='neighborhood (u.h.f)',
                           featureidkey='properties.GEONAME',
                           color='poverty rate (2017-2021)',
                           hover_data=['neighborhood (u.h.f)'],
                           title='Poverty rate (2017-2021) by neighborhood',
                           center = {'lat': 40.73, 'lon': -73.98},
                           zoom=10,
                           color_continuous_scale="YlOrRd",
                           mapbox_style='carto-positron')

fig_pov_neigh_map.update_layout(height=1010)

#display
fig_pov_neigh_map.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="24c0dce9-e269-4089-9d34-5193b68fb62b" class="plotly-graph-div" style="height:1010px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24c0dce9-e269-4089-9d34-5193b68fb62b")) {                    Plotly.newPlot(                        "24c0dce9-e269-4089-9d34-5193b68fb62b",                        [{"coloraxis":"coloraxis","customdata":[["Kingsbridge - Riverdale"],["Northeast Bronx"],["Fordham - Bronx Park"],["Pelham - Throgs Neck"],["Crotona - Tremont"],["High Bridge - Morrisania"],["Hunts Point - Mott Haven"],["Greenpoint"],["Downtown  - Heights - Slope"],["Bedford Stuyvesant - Crown Heights"],["East New York"],["Sunset Park"],["Borough Park"],["East Flatbush - Flatbush"],["Canarsie - Flatlands"],["Bensonhurst - Bay Ridge"],["Coney Island - Sheepshead Bay"],["Williamsburg - Bushwick"],["Washington Heights - Inwood"],["Central Harlem - Morningside Heights"],["East Harlem"],["Upper West Side"],["Upper East Side"],["Chelsea - Clinton"],["Gramercy Park -  Murray Hill"],["Greenwich Village - Soho"],["Union Square - Lower East Side"],["Lower Manhattan"],["Long Island City - Astoria"],["West Queens"],["Flushing - Clearview"],["Bayside - Little Neck"],["Ridgewood - Forest Hills"],["Fresh Meadows"],["Southwest Queens"],["Jamaica"],["Southeast Queens"],["Rockaways"],["Port  Richmond"],["Stapleton - St. George"],["Willowbrook"],["South Beach - Tottenville"]],"featureidkey":"properties.GEONAME","geojson":{"type":"FeatureCollection","features":[{"type":"Feature","properties":{"GEOCODE":101,"GEONAME":"Kingsbridge - Riverdale","BOROUGH":"Bronx"},"geometry":{"type":"Polygon","coordinates":[[[-73.877928,40.905562],[-73.902168,40.912841],[-73.910731,40.915775],[-73.914292,40.904242],[-73.915148,40.903069],[-73.918149,40.89411],[-73.91976,40.89113],[-73.920557,40.887201],[-73.924678,40.8789],[-73.922779,40.878849],[-73.919803,40.876419],[-73.913012,40.874791],[-73.910341,40.873842],[-73.908772,40.871777],[-73.911053,40.866308],[-73.914343,40.862519],[-73.913605,40.862205],[-73.912918,40.861961],[-73.909044,40.862673],[-73.907102,40.867886],[-73.902659,40.870579],[-73.900964,40.875355],[-73.896691,40.880156],[-73.896377,40.881823],[-73.887102,40.882925],[-73.887068,40.8844],[-73.881243,40.882708],[-73.877987,40.887034],[-73.880404,40.892828],[-73.880107,40.8952],[-73.877928,40.905562]]]},"id":"101"},{"type":"Feature","properties":{"GEOCODE":102,"GEONAME":"Northeast Bronx","BOROUGH":"Bronx"},"geometry":{"type":"Polygon","coordinates":[[[-73.815044,40.889002],[-73.822852,40.891207],[-73.823268,40.889989],[-73.838046,40.894142],[-73.839648,40.897327],[-73.83925,40.8995],[-73.841386,40.904159],[-73.844761,40.904242],[-73.845388,40.905639],[-73.850204,40.907478],[-73.853536,40.907465],[-73.857529,40.904793],[-73.857232,40.903024],[-73.859682,40.902294],[-73.859326,40.900589],[-73.874248,40.904806],[-73.877928,40.905562],[-73.880107,40.8952],[-73.870484,40.896642],[-73.861361,40.894661],[-73.865371,40.886874],[-73.855884,40.883861],[-73.856266,40.88315],[-73.861073,40.87447],[-73.861794,40.857986],[-73.861836,40.857383],[-73.849483,40.858107],[-73.83802,40.856947],[-73.833077,40.857537],[-73.830661,40.857069],[-73.827414,40.859595],[-73.826117,40.856677],[-73.823081,40.857017],[-73.818672,40.858806],[-73.816604,40.860935],[-73.819368,40.859249],[-73.821199,40.859441],[-73.819113,40.862],[-73.820216,40.862923],[-73.821004,40.868046],[-73.823726,40.869758],[-73.823938,40.874073],[-73.821877,40.879246],[-73.820834,40.884855],[-73.819359,40.885727],[-73.81534,40.886778],[-73.815044,40.889002]]]},"id":"102"},{"type":"Feature","properties":{"GEOCODE":103,"GEONAME":"Fordham - Bronx Park","BOROUGH":"Bronx"},"geometry":{"type":"Polygon","coordinates":[[[-73.856266,40.88315],[-73.855884,40.883861],[- ...

# %% [markdown]
# #### f. Where are HIV service centers located? Are they near neighborhoods that have high HIV case counts?

# %% [markdown]
# 🔴 Finally, since it would help the city to know how best to serve HIV-positive populations, I looked into the location of different organizations offering HIV services. I first mapped them out in New York City, and then laid these points on top of the earlier map with HIV diagnoses per 100,000 by neighborhood.
#
# On this two-layer map, we can see that most organizations providing HIV services are largely situated in neighborhoods with a high burden of HIV cases. However, there are a few neighborhoods that are rather underserved (meaning there are no organizations offering HIV services in the area) despite having HIV diagnosis per 100,000 higher than 2000, namely:
# - Washington Heights
# - Ridgewood - Forest Hills
# - East New York
#
# These are areas which these organizations can expand into to offer HIV services.

# %%
# Create the map
fig_hiv_serv = px.scatter_mapbox(df_hiv_serv,
                        lat="Latitude",
                        lon="Longitude",
                        hover_name="FacilityName",
                        zoom=10)

# Use open-street-map as base map
fig_hiv_serv.update_layout(mapbox_style="open-street-map")
fig_hiv_serv.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

# Show the figure in browser
fig_hiv_serv.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2e3777e1-8e72-44c7-a1fd-88ebc1ece572" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e3777e1-8e72-44c7-a1fd-88ebc1ece572")) {                    Plotly.newPlot(                        "2e3777e1-8e72-44c7-a1fd-88ebc1ece572",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eLatitude=%{lat}\u003cbr\u003eLongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["African Services Committee","After Hours Project","AIDS Center of Queens County","APICHA Community Health Center","Argus Community","Bailey House","Betances Health Center","BOOM!Health","Bridging Access to Care","Bronx Works","BronxCare Health System","Brooklyn Legal Services","Brooklyn Plaza Medical Center","Callen-Lorde Community Health Center","CAMBA","Community Health Action of Staten Island (CHASI)","Community Health Center of Richmond","Council on Adoptable Children","Destination Tomorrow","Exponents","Family Services Network of New York","Gay Men's Health Crisis (GMHC)","God's Love We Deliver","Haitian Centers Council","Harlem United","Hispanic AIDS Forum","Housing Solutions of New York","Housing Works","Sun River Health (formally HRH)","Hudson Valley Community Services","Interfaith Medical Center","Joseph P. Addabbo Family Health Center","La Casa De Salud, Inc.","La Nueva Esperanza","Legal Aid Society of Rockland County","Legal Services of the Hudson Valley","Lifting Up Westchester","Manhattan Legal Services","Mobilization for Justice, Inc., formerly known as MFY Legal Services, Inc.","Morris Heights Health Center, Inc.","Mount Sinai Beth Israel Project SHARE","Mount Sinai Health System","Mount Vernon Neighborhood Health Center","New York Presbyterian Hospitals","NYC Health + Hospitals - Elmhurst Hospital Center","NYC Health + Hospitals - Harlem Hospital Center","NYC Health + Hospitals - Jacobi Medical Center","NYC Health + Hospitals - Kings County Hospital Center","NYC Health + Hospitals - Queens Hospital Center","NYC Health + Hospitals - Woodhull Medical and Mental Health Center","NYU Langone - Family Health Centers at NYU Langone","OnPoint NYC","Open Door Family Medical Center","Planned Parenthood of Greater New York","Project Hospitality","Services for the Underserved","St. Ann's Corner of Harm Reduction","St. John's Riverside Hospital","STAR Program - SUNY Downstate","Sun River Health (formally HRH)","SUNY Downstate Medical Center","The Alliance for Positive Change","The Family Center","The Fortune Society, Inc.","The Institute for Family Health","The Legal Aid Society","Together Our Unity Can Heal","Tolentine Zeiser Community Life Center","VIP Community Services","Westchester County Department of Health","Wyckoff Heights Medical Center"],"lat":[40.813002,40.692107,40.704249,40.718702,40.820438,40.80425,40.713911,40.820438,40.650448,40.851063,40.831721,40.690793,40.693377,40.742905,40.639723,40.64139,40.635621,40.755792,40.81535,40.745428,40.682568,40.753541,40.725575,40.651188,40.807457,40.803389,40.696771,40.692217,null,null,40.677816,40.685076,40.82288,40.706805,null,null,null,40.806522,40.708497,40.854655,40.739538,40.790443,null,40.872385,40.744416,40.814358,40.857427,40.65576,40.71725,40.700528,40.645329,40.802126,null,40.725564,40.629461,40.73948,40.820727,null,40.655743,null,40.655743,40.749989,40.680495,40.750466,40.737122,40.70727,null,40.859954,40.845391,null,40.704636],"legendgroup":"","lon":[-73.953849,-73.926657,-73.797921,-74.002464,-73.904737,-73.937099,-73.983847,-73.904737,-73.957663,-73.908004,-73.903756,-73.991825,-73.976074,-74.00227,-73.954484,-74.075957,-74.135021,-73.99225,-73.915961,-73.992872,-73.90988,-73.998758,-74.003994,-73.941712,-73.945704,-7 ...

# %% [markdown]
# Mapping HIV service centers and HIV cases per 100,000 (2016-2021) on NYC map

# %%
# import other plotly setup
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create a new figure that will contain both maps
fig = go.Figure()

# Add the choropleth layer
fig.add_trace(go.Choroplethmapbox(
    geojson=geojson,
    locations=hiv_uhf['neighborhood (u.h.f)'],
    z=hiv_uhf['hiv diagnoses per 100,000 population'],
    featureidkey='properties.GEONAME',
    colorscale="YlOrRd",
    marker_opacity=0.5,
    marker_line_width=0.5,
    colorbar=dict(
        title="HIV diagnoses<br>per 100,000",
        x=0.01,
        xpad=0
    ),
    hovertemplate='<b>%{location}</b><br>HIV diagnoses per 100,000: %{z}<extra></extra>'
))

# Add the scatter mapbox layer for HIV service facilities
fig.add_trace(go.Scattermapbox(
    lat=df_hiv_serv["Latitude"],
    lon=df_hiv_serv["Longitude"],
    mode='markers',
    marker=dict(
        size=8,
        color='blue',
        opacity=0.8
    ),
    text=df_hiv_serv["FacilityName"],
    hoverinfo='text',
    hovertemplate='<b>%{text}</b><extra></extra>',
    name='HIV Services'
))

# Update layout with proper styling
fig.update_layout(
    title="HIV Diagnoses per 100,000 by Neighborhood and Service Locations in NYC (2016-2021)",
    mapbox_style="carto-positron",
    mapbox=dict(
        center=dict(lat=40.73, lon=-73.98),
        zoom=10
    ),
    height=1100,
    margin={"r":0, "t":40, "l":0, "b":0},
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="right",
        x=1
    )
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0036c081-787c-4db0-9899-0994077e2bf2" class="plotly-graph-div" style="height:1100px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0036c081-787c-4db0-9899-0994077e2bf2")) {                    Plotly.newPlot(                        "0036c081-787c-4db0-9899-0994077e2bf2",                        [{"colorbar":{"title":{"text":"HIV diagnoses\u003cbr\u003eper 100,000"},"x":0.01,"xpad":0},"colorscale":[[0.0,"rgb(255,255,204)"],[0.125,"rgb(255,237,160)"],[0.25,"rgb(254,217,118)"],[0.375,"rgb(254,178,76)"],[0.5,"rgb(253,141,60)"],[0.625,"rgb(252,78,42)"],[0.75,"rgb(227,26,28)"],[0.875,"rgb(189,0,38)"],[1.0,"rgb(128,0,38)"]],"featureidkey":"properties.GEONAME","geojson":{"type":"FeatureCollection","features":[{"type":"Feature","properties":{"GEOCODE":101,"GEONAME":"Kingsbridge - Riverdale","BOROUGH":"Bronx"},"geometry":{"type":"Polygon","coordinates":[[[-73.877928,40.905562],[-73.902168,40.912841],[-73.910731,40.915775],[-73.914292,40.904242],[-73.915148,40.903069],[-73.918149,40.89411],[-73.91976,40.89113],[-73.920557,40.887201],[-73.924678,40.8789],[-73.922779,40.878849],[-73.919803,40.876419],[-73.913012,40.874791],[-73.910341,40.873842],[-73.908772,40.871777],[-73.911053,40.866308],[-73.914343,40.862519],[-73.913605,40.862205],[-73.912918,40.861961],[-73.909044,40.862673],[-73.907102,40.867886],[-73.902659,40.870579],[-73.900964,40.875355],[-73.896691,40.880156],[-73.896377,40.881823],[-73.887102,40.882925],[-73.887068,40.8844],[-73.881243,40.882708],[-73.877987,40.887034],[-73.880404,40.892828],[-73.880107,40.8952],[-73.877928,40.905562]]]},"id":"101"},{"type":"Feature","properties":{"GEOCODE":102,"GEONAME":"Northeast Bronx","BOROUGH":"Bronx"},"geometry":{"type":"Polygon","coordinates":[[[-73.815044,40.889002],[-73.822852,40.891207],[-73.823268,40.889989],[-73.838046,40.894142],[-73.839648,40.897327],[-73.83925,40.8995],[-73.841386,40.904159],[-73.844761,40.904242],[-73.845388,40.905639],[-73.850204,40.907478],[-73.853536,40.907465],[-73.857529,40.904793],[-73.857232,40.903024],[-73.859682,40.902294],[-73.859326,40.900589],[-73.874248,40.904806],[-73.877928,40.905562],[-73.880107,40.8952],[-73.870484,40.896642],[-73.861361,40.894661],[-73.865371,40.886874],[-73.855884,40.883861],[-73.856266,40.88315],[-73.861073,40.87447],[-73.861794,40.857986],[-73.861836,40.857383],[-73.849483,40.858107],[-73.83802,40.856947],[-73.833077,40.857537],[-73.830661,40.857069],[-73.827414,40.859595],[-73.826117,40.856677],[-73.823081,40.857017],[-73.818672,40.858806],[-73.816604,40.860935],[-73.819368,40.859249],[-73.821199,40.859441],[-73.819113,40.862],[-73.820216,40.862923],[-73.821004,40.868046],[-73.823726,40.869758],[-73.823938,40.874073],[-73.821877,40.879246],[-73.820834,40.884855],[-73.819359,40.885727],[-73.81534,40.886778],[-73.815044,40.889002]]]},"id":"102"},{"type":"Feature","properties":{"GEOCODE":103,"GEONAME":"Fordham - Bronx Park","BOROUGH":"Bronx"},"geometry":{"type":"Polygon","coordinates":[[[-73.856266,40.88315],[-73.855884,40.883861],[-73.865371,40.886874],[-73.861361,40.894661],[-73.870484,40.896642],[-73.880107,40.8952],[-73.880404,40.892828],[-73.877987,40.887034],[-73.881243,40.882708],[-73.887068,40.8844],[-73.887102,40.882925],[-73.896377,40.881823],[-73.896691,40.880156],[-73.900964,40.875355],[-73.902659,40.870579],[-73.907102,40.867886],[-73.909044,40.862673],[-73.912918,40.861961],[-73.914444,40.859781],[-73.910994,40.860595],[-73.896038,40.856408],[-73.889459,40.853221],[-73.88382,40.851502],[-73.881667,40.853349],[-73.88059,40.85696],[-73.877241,40.855401],[-73.868856,40.857223],[-73.868381,40.857812],[-73.861794,40.857986],[-73.861073,40.87447],[-73.856266,40.88315]]]},"id":"103"},{"type":"Feature","properties":{"GEOCODE":104,"GEONAME":"Pelham - Throgs  ...

# %% [markdown]
# ## VI. Results and Revisiting Hypotheses

# %% [markdown]
# 🔴  **1. HIV Rates are highest in parts of Manhattan, the Bronx and Brooklyn**
#
# My hypothesis that the Bronx and Brooklyn, as well as Black individuals, would have the highest number of HIV cases was largely confirmed, with one slight deviation. **Manhattan** turned out to have the highest rate of HIV diagnoses per 100,000 people, which wasn't what I expected. This is largely driven by high cases in Chelsea - Clinton and Greenwich Village - Soho, areas which have a large population of gay men. However, both **Brooklyn** and the **Bronx** showed significant rates of HIV diagnoses, especially in neighborhoods like **Bedford Stuyvesant - Crown Heights** and **Hunts Point - Mott Haven**, which aligns with my prediction for these boroughs.
#
# 🔴  **2. HIV Rates are highest among men and Black and Latino individuals**
#
# Regarding demographics, I was correct in predicting that **Black individuals** would have the highest rate of HIV diagnoses per 100,000, which was consistent with my hypothesis. This trend supports the historical and social factors that have disproportionately affected Black communities. As for gender, I was also right in expecting that **men** would have a higher incidence of HIV than women. The finding that men accounted for 85% of new HIV diagnoses confirms the historical trend of HIV being more common among men, particularly gay men.
#
# 🔴 **3. There is a weak positive association between HIV and Poverty**
#
# I suspected there would be a correlation between HIV and poverty, but the relationship turned out to be weaker than I anticipated. While there was indeed a **small positive correlation** between the two, the **weak strength** of the association was surprising. The R² value of 0.091 suggested that while there may be some connection between higher poverty rates and increased HIV diagnoses, poverty does not fully explain the trends. This indicates that other factors likely play a role, so my hypothesis about a strong connection between poverty and HIV was only partially correct.
#
# 🔴 **4. HIV Services are generally available in high-burden areas, with a few exceptions**
#
# My hypothesis that HIV services are generally available in high-burden areas was mostly confirmed. The analysis showed that most HIV service organizations are located in neighborhoods with high rates of HIV diagnoses, which supports my assumption. However, I was surprised to find that some areas, like **Washington Heights** and **Ridgewood - Forest Hills**, had relatively high HIV rates but were **underserved** in terms of HIV services. This indicates that while services are typically located in high-burden areas, there are still some gaps, especially in neighborhoods that might be emerging or harder to access for healthcare providers.
#
# ### Summary
#
# In the end, most of my hypotheses were confirmed, particularly regarding the higher rates of HIV among Black individuals and men, as well as the general presence of HIV services in high-burden areas. However, the weak correlation between HIV and poverty suggests that other factors beyond poverty contribute to the epidemic, such as gender, race and neighborhood. Further, the final graph is a call to improve access to HIV services to underserved neighborhoods in the Bronx and Brooklyn with a relatively high burden of HIV.
